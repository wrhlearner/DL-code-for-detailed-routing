# %%
import os
import torch
import numpy as np
import random
from utils import buildDataset

# %% [markdown]
# ## build dataset

# %%
defaultStrategy = "./DefaultStrategy.txt"
defaultOutput = "./defaultOutputs.txt"
strategy = "./strategy.txt"
output = "./outputs.txt"
dataset = buildDataset.getData(strategy, output, defaultStrategy, defaultOutput)

# %%
len(dataset)
# Out:
# 77

# %%
dataset[0]
# Out:
# [[{'size': 7,
#    'offset': 0,
#    'mazeEndIter': 3,
#    'MarkerCost': 0,
#    'FixedShapeCost': 8,
#    'Decay': 0.95,
#    'ripupMode': 0,
#    'followGuide': 1},
#   10178],
#  [{'size': 7,
#    'offset': -2,
#    'mazeEndIter': 3,
#    'MarkerCost': 8,
#    'FixedShapeCost': 8,
#    'Decay': 0.95,
#    'ripupMode': 0,
#    'followGuide': 1},
#   569],
#  [{'size': 7,
#    'offset': -5,
#    'mazeEndIter': 3,
#    'MarkerCost': 8,
#    'FixedShapeCost': 8,
#    'Decay': 0.95,
#    'ripupMode': 0,
#    'followGuide': 1},
#   499],
#  [{'size': 7,
#    'offset': 0,
#    'mazeEndIter': 8,
#    'MarkerCost': 32,
#    'FixedShapeCost': 16,
#    'Decay': 0.95,
#    'ripupMode': 1,
#    'followGuide': 0},
#   1],
#  [{'size': 7,
#    'offset': -1,
#    'mazeEndIter': 8,
#    'MarkerCost': 32,
#    'FixedShapeCost': 16,
#    'Decay': 0.95,
#    'ripupMode': 1,
#    'followGuide': 0},
#   0]]

# %% [markdown]
# # Turning datapoint to tensor

# %% [markdown]
# To represent a single data point input, we use a tensor of size <No_Strategy x 1 x 9>. (9 includes 8 DRC sequence items, and 1 output DRC value)

# %%
Dataset, Label = buildDataset.LSTMdatasetToTensor(dataset)

# %%
len(Dataset)
# Out:
# 77

# %%
Dataset[0]
# Out:
# tensor([[[ 7.0000e+00,  0.0000e+00,  3.0000e+00,  0.0000e+00,  8.0000e+00,
#            9.5000e-01,  0.0000e+00,  1.0000e+00,  1.0178e+04]],
#
#         [[ 7.0000e+00, -2.0000e+00,  3.0000e+00,  8.0000e+00,  8.0000e+00,
#            9.5000e-01,  0.0000e+00,  1.0000e+00,  1.0178e+04]],
#
#         [[ 7.0000e+00, -5.0000e+00,  3.0000e+00,  8.0000e+00,  8.0000e+00,
#            9.5000e-01,  0.0000e+00,  1.0000e+00,  5.6900e+02]],
#
#         [[ 7.0000e+00,  0.0000e+00,  8.0000e+00,  3.2000e+01,  1.6000e+01,
#            9.5000e-01,  1.0000e+00,  0.0000e+00,  4.9900e+02]],
#
#         [[ 7.0000e+00, -1.0000e+00,  8.0000e+00,  3.2000e+01,  1.6000e+01,
#            9.5000e-01,  1.0000e+00,  0.0000e+00,  1.0000e+00]]])

# %%
Dataset[0].size()
# Out:
# torch.Size([5, 1, 9])

# %%
Label[0]
# Out:
# tensor([[[1.0178e+04]],
#
#         [[5.6900e+02]],
#
#         [[4.9900e+02]],
#
#         [[1.0000e+00]],
#
#         [[0.0000e+00]]])

# %%
Label[0].size()
# Out:
# torch.Size([5, 1, 1])

# %% [markdown]
# # train-test split of the dataset

# %%
X_train, Y_train, X_test, Y_test = buildDataset.LSTMsplitDataset(Dataset, Label, trainSize = 0.7)

# %%
len(X_train)
# Out:
# 53

# %%
len(X_test)
# Out:
# 24

# %%
X_train[0]
# Out:
# tensor([[[ 7.0000e+00,  0.0000e+00,  4.0000e+00,  3.0000e+00,  2.9000e+01,
#            5.7057e-01,  0.0000e+00,  1.0000e+00,  3.2846e+04]],
#
#         [[ 7.0000e+00, -1.0000e+00,  4.8000e+01,  1.3000e+01,  5.0000e+00,
#            8.5135e-01,  0.0000e+00,  1.0000e+00,  3.2846e+04]],
#
#         [[ 7.0000e+00, -2.0000e+00,  5.5000e+01,  7.0000e+00,  3.7000e+01,
#            9.8298e-01,  0.0000e+00,  1.0000e+00,  1.9620e+03]],
#
#         [[ 7.0000e+00, -3.0000e+00,  1.1000e+01,  8.0000e+00,  5.6000e+01,
#            5.4004e-01,  1.0000e+00,  0.0000e+00,  1.4820e+03]],
#
#         [[ 7.0000e+00, -4.0000e+00,  1.4000e+01,  1.1000e+01,  7.0000e+01,
#            5.0751e-01,  1.0000e+00,  0.0000e+00,  1.0000e+00]]])

# %%
X_train[0].size()
# Out:
# torch.Size([5, 1, 9])

# %%
Y_train[0]
# Out:
# tensor([[[3.2846e+04]],
#
#         [[1.9620e+03]],
#
#         [[1.4820e+03]],
#
#         [[1.0000e+00]],
#
#         [[0.0000e+00]]])

# %%
Y_train[0].size()
# Out:
# torch.Size([5, 1, 1])

# %% [markdown]
# # Creating the Network

# %%
# reference: https://pytorch.org/tutorials/beginner/nlp/sequence_models_tutorial.html
import torch.nn as nn

class LSTM(nn.Module):
    def __init__(self, input_size, numLayers):
        super(LSTM, self).__init__()
        self.numLayers = numLayers
        self.mapping = nn.Sigmoid()

        self.lstm = nn.LSTM(input_size, 1, num_layers=self.numLayers)

    def forward(self, inputData):
        intput = self.mapping(inputData)
        output, _ = self.lstm(intput)
        return output

# %%
n_input = len(X_train[0][0][0])
numLayers = 128

# %%
n_input
# Out:
# 9

# %%
model = LSTM(n_input, numLayers)

# %% [markdown]
# # Run a step of the network

# %% [markdown]
# To run a step of this network we need to pass an input (in our case, the Tensor for the current strategy) and a previous hidden state (which we initialize as zeros at first). We’ll get back the output (probability of drcs) and a next hidden state (which we keep for the next step).

# %%
import torch

# %%
inputStrategy = X_train[0]

output = model(inputStrategy)

# %%
output
# Out:
# tensor([[[-0.1191]],
#
#         [[-0.1499]],
#
#         [[-0.1581]],
#
#         [[-0.1604]],
#
#         [[-0.1612]]], grad_fn=<MkldnnRnnLayerBackward0>)

# %% [markdown]
# # Training

# %%
criterion = nn.MSELoss()

# %%
learning_rate = 0.001 # If you set this too high, it might explode. If too low, it might not learn

# %%
import torch.optim as optim
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
import time
import math

# %%
def timeSince(since):
    now = time.time()
    s = now - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

start = time.time()

# %%
n_iters = 1000
print_every = 10
plot_every = 1

# %%
def train(x, y):

    model.zero_grad()

    output = model(x)
    
    loss = criterion(output, y)
    loss.backward()

    optimizer.step()

    return output, loss.item()

# %%
# Keep track of losses for plotting
current_loss = 0
all_losses = []

# %%
for iter in range(1, n_iters + 1):
    # randomly generate an index in training set
    index = random.randint(0, len(X_train) - 1)
    x = X_train[index]
    y = Y_train[index]
    output, loss = train(x, y)
    current_loss += loss

    # Print ``iter`` number, loss, name and guess
    if iter % print_every == 0:
        print('%d %d%% (%s) %.4f' % (iter, iter / n_iters * 100, timeSince(start), loss))

    # Add current loss avg to list of losses
    if iter % plot_every == 0:
        all_losses.append(current_loss / plot_every)
        current_loss = 0
# Out:
# 10 1% (0m 2s) 343960256.0000
# 20 2% (0m 5s) 30637748.0000
# 30 3% (0m 8s) 1129064576.0000
# 40 4% (0m 10s) 25832334.0000
# 50 5% (0m 13s) 30637690.0000
# 60 6% (0m 16s) 29064490.0000
# 70 7% (0m 20s) 735422912.0000
# 80 8% (0m 23s) 57054312.0000
# 90 9% (0m 26s) 9915919.0000
# 100 10% (0m 28s) 121283952.0000
# 110 11% (0m 31s) 673689536.0000
# 120 12% (0m 34s) 125873528.0000
# 130 13% (0m 37s) 1129063552.0000
# 140 14% (0m 40s) 735422144.0000
# 150 15% (0m 43s) 57657688.0000
# 160 16% (0m 46s) 6813202.0000
# 170 17% (0m 49s) 52843524.0000
# 180 18% (0m 52s) 6813183.5000
# 190 19% (0m 55s) 155524608.0000
# 200 20% (0m 58s) 104036504.0000
# 210 21% (1m 1s) 173221184.0000
# 220 22% (1m 3s) 9915779.0000
# 230 23% (1m 6s) 25831972.0000
# 240 24% (1m 9s) 25831954.0000
# 250 25% (1m 12s) 125872896.0000
# 260 26% (1m 15s) 1632438400.0000
# 270 27% (1m 18s) 57053888.0000
# 280 28% (1m 21s) 328580.8125
# 290 28% (1m 24s) 52843160.0000
# 300 30% (1m 27s) 1129061760.0000
# 310 31% (1m 30s) 20833028.0000
# 320 32% (1m 32s) 104036152.0000
# 330 33% (1m 35s) 216981472.0000
# 340 34% (1m 38s) 1632437888.0000
# 350 35% (1m 41s) 12873.0244
# 360 36% (1m 44s) 122993992.0000
# 370 37% (1m 47s) 328564.8750
# 380 38% (1m 50s) 343959616.0000
# 390 39% (1m 53s) 1150979328.0000
# 400 40% (1m 56s) 25831740.0000
# 410 41% (1m 58s) 360288.5312
# 420 42% (2m 1s) 52842916.0000
# 430 43% (2m 4s) 104035912.0000
# 440 44% (2m 7s) 184567936.0000
# 450 45% (2m 10s) 30637078.0000
# 460 46% (2m 13s) 2979886592.0000
# 470 47% (2m 16s) 216981072.0000
# 480 48% (2m 19s) 216981024.0000
# 490 49% (2m 22s) 735419200.0000
# 500 50% (2m 25s) 1129060352.0000
# 510 51% (2m 28s) 57657016.0000
# 520 52% (2m 31s) 25831578.0000
# 530 53% (2m 33s) 216980864.0000
# 540 54% (2m 36s) 30636950.0000
# 550 55% (2m 39s) 29063750.0000
# 560 56% (2m 42s) 25831526.0000
# 570 56% (2m 45s) 1150978176.0000
# 580 57% (2m 47s) 104035544.0000
# 590 59% (2m 50s) 10841.7861
# 600 60% (2m 53s) 2979885312.0000
# 610 61% (2m 56s) 1572580992.0000
# 620 62% (2m 59s) 184567360.0000
# 630 63% (3m 1s) 57053336.0000
# 640 64% (3m 4s) 122993656.0000
# 650 65% (3m 7s) 1632435072.0000
# 660 66% (3m 10s) 1632435072.0000
# 670 67% (3m 12s) 360265.5938
# 680 68% (3m 15s) 104035264.0000
# 690 69% (3m 18s) 1129059072.0000
# 700 70% (3m 21s) 1150977152.0000
# 710 71% (3m 24s) 1129058944.0000
# 720 72% (3m 27s) 6812778.5000
# 730 73% (3m 30s) 30636678.0000
# 740 74% (3m 33s) 360257.8125
# 750 75% (3m 36s) 155522320.0000
# 760 76% (3m 39s) 20749866.0000
# 770 77% (3m 42s) 52842148.0000
# 780 78% (3m 45s) 122993424.0000
# 790 79% (3m 48s) 52842088.0000
# 800 80% (3m 51s) 328483.4688
# 810 81% (3m 54s) 125871000.0000
# 820 82% (3m 57s) 360247.2812
# 830 83% (4m 0s) 122993320.0000
# 840 84% (4m 3s) 1150975616.0000
# 850 85% (4m 6s) 30636432.0000
# 860 86% (4m 9s) 1632432512.0000
# 870 87% (4m 11s) 735415616.0000
# 880 88% (4m 15s) 57678516.0000
# 890 89% (4m 18s) 57052712.0000
# 900 90% (4m 20s) 47695.3984
# 910 91% (4m 23s) 6730.8594
# 920 92% (4m 26s) 360227.8438
# 930 93% (4m 29s) 1572574976.0000
# 940 94% (4m 31s) 29062972.0000
# 950 95% (4m 34s) 360221.2188
# 960 96% (4m 37s) 122992904.0000
# 970 97% (4m 40s) 57052440.0000
# 980 98% (4m 43s) 1753090176.0000
# 990 99% (4m 46s) 121281008.0000
# 1000 100% (4m 49s) 1129054848.0000

# %% [markdown]
# # Result evaluation

# %%
# print("MSE: %.2f" % best_mse)
# print("RMSE: %.2f" % np.sqrt(best_mse))
# plt.plot(history)
# plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

plt.figure()
plt.plot(all_losses)

# %%
all_losses
# Out:
# [328647.96875,
#  243371072.0,
#  1150982784.0,
#  1150982784.0,
#  155525584.0,
#  1129064832.0,
#  47793.2421875,
#  104037144.0,
#  328645.6875,
#  343960256.0,
#  735423552.0,
#  1129064704.0,
#  1129064704.0,
#  9915996.0,
#  1632441984.0,
#  155525504.0,
#  57681088.0,
#  328643.28125,
#  29064566.0,
#  30637748.0,
#  10857.146484375,
#  1129064576.0,
#  104037080.0,
#  328641.875,
#  328641.65625,
#  1150982528.0,
#  735423296.0,
#  1753102464.0,
#  20833398.0,
#  1129064576.0,
#  57657940.0,
#  121284176.0,
#  9915976.0,
#  30637724.0,
#  1572588800.0,
#  1753102464.0,
#  10856.626953125,
#  121284160.0,
#  1632441856.0,
#  25832334.0,
#  1753102464.0,
#  121284136.0,
#  57054392.0,
#  6761.873046875,
#  2979891968.0,
#  20833376.0,
#  1632441344.0,
#  328635.75,
#  47787.7890625,
#  30637690.0,
#  25832310.0,
#  122994552.0,
#  1150982272.0,
#  1129064320.0,
#  6813292.0,
#  9915950.0,
#  1632441344.0,
#  328633.5625,
#  1753102336.0,
#  29064490.0,
#  1129064320.0,
#  121284072.0,
#  338668448.0,
#  20751056.0,
#  104036944.0,
#  30637668.0,
#  338668416.0,
#  20751050.0,
#  2979891456.0,
#  735422912.0,
#  9915937.0,
#  121284048.0,
#  338668416.0,
#  57054324.0,
#  20751036.0,
#  343960096.0,
#  20751034.0,
#  1129064064.0,
#  25832260.0,
#  57054312.0,
#  328628.59375,
#  2979891456.0,
#  2979891200.0,
#  121284016.0,
#  121283992.0,
#  1129064064.0,
#  6813265.5,
#  30637632.0,
#  122994472.0,
#  9915919.0,
#  30637626.0,
#  125873624.0,
#  155525104.0,
#  1753101824.0,
#  47782.70703125,
#  52843728.0,
#  25832236.0,
#  104036856.0,
#  57657804.0,
#  121283952.0,
#  6813254.0,
#  1632441216.0,
#  57680812.0,
#  30637606.0,
#  1753101696.0,
#  25832216.0,
#  173221616.0,
#  30637604.0,
#  121283944.0,
#  673689536.0,
#  1753101440.0,
#  1572587392.0,
#  6813244.0,
#  57054252.0,
#  216982368.0,
#  9915895.0,
#  30637578.0,
#  57657760.0,
#  57657760.0,
#  125873528.0,
#  104036792.0,
#  673689536.0,
#  173221552.0,
#  122994432.0,
#  1753101440.0,
#  328618.78125,
#  57054220.0,
#  243370800.0,
#  6758.83251953125,
#  1129063552.0,
#  10853.822265625,
#  1572587264.0,
#  184569104.0,
#  243370752.0,
#  673689280.0,
#  1632440448.0,
#  30637548.0,
#  338668352.0,
#  9915873.0,
#  735422144.0,
#  121283856.0,
#  57680704.0,
#  735422144.0,
#  173221488.0,
#  216982272.0,
#  173221456.0,
#  6758.13134765625,
#  20750892.0,
#  735422144.0,
#  57657688.0,
#  6757.986328125,
#  47776.2265625,
#  125873376.0,
#  25832136.0,
#  338668352.0,
#  30637514.0,
#  2979890688.0,
#  9915855.0,
#  343960032.0,
#  6813202.0,
#  104036664.0,
#  47775.28125,
#  216982192.0,
#  2979890688.0,
#  20750864.0,
#  184568976.0,
#  1129063168.0,
#  1129063168.0,
#  1129063168.0,
#  52843524.0,
#  57680612.0,
#  47774.1015625,
#  1753100928.0,
#  25832100.0,
#  1753100928.0,
#  1572586624.0,
#  173221344.0,
#  360313.03125,
#  25832092.0,
#  6813183.5,
#  30637472.0,
#  673688960.0,
#  1150981248.0,
#  328605.3125,
#  1632439808.0,
#  1753100800.0,
#  155524656.0,
#  12878.7333984375,
#  122994296.0,
#  155524608.0,
#  1632439680.0,
#  20750800.0,
#  121283672.0,
#  1572586112.0,
#  1150980992.0,
#  1753100416.0,
#  1753100416.0,
#  25832050.0,
#  10851.560546875,
#  104036504.0,
#  2979889408.0,
#  1129062784.0,
#  2979889408.0,
#  29064236.0,
#  173221184.0,
#  57657556.0,
#  1129062784.0,
#  121283608.0,
#  1129062784.0,
#  173221184.0,
#  173221184.0,
#  25832012.0,
#  243370544.0,
#  1572585600.0,
#  57680428.0,
#  20750734.0,
#  1150980608.0,
#  1572585600.0,
#  30637388.0,
#  9915779.0,
#  47766.55078125,
#  216981920.0,
#  10850.5732421875,
#  104036416.0,
#  673688448.0,
#  2979889408.0,
#  2979889152.0,
#  1632439296.0,
#  6754.51806640625,
#  25831972.0,
#  57053972.0,
#  57657492.0,
#  1632438912.0,
#  10850.166015625,
#  104036376.0,
#  1129062528.0,
#  673688256.0,
#  12876.3447265625,
#  25831956.0,
#  25831954.0,
#  6813112.0,
#  735420992.0,
#  52843276.0,
#  328587.8125,
#  125872920.0,
#  104036328.0,
#  184568576.0,
#  360302.5,
#  104036328.0,
#  125872896.0,
#  184568528.0,
#  6753.63623046875,
#  1150980480.0,
#  173220976.0,
#  57053908.0,
#  216981728.0,
#  360301.6875,
#  29064134.0,
#  343959840.0,
#  1632438400.0,
#  57053900.0,
#  173220944.0,
#  30637312.0,
#  6813096.0,
#  57657420.0,
#  20750626.0,
#  6753.19775390625,
#  338668160.0,
#  2979888640.0,
#  57053888.0,
#  2979888640.0,
#  1572584704.0,
#  57680232.0,
#  12875.212890625,
#  735420736.0,
#  47760.25,
#  6752.83203125,
#  25831894.0,
#  343959776.0,
#  328580.8125,
#  125872776.0,
#  57053864.0,
#  9915720.0,
#  216981600.0,
#  360298.75,
#  1632438400.0,
#  20750588.0,
#  673688000.0,
#  30637276.0,
#  52843160.0,
#  29064084.0,
#  243370384.0,
#  52843160.0,
#  10848.56640625,
#  6813072.0,
#  216981600.0,
#  343959744.0,
#  6752.21728515625,
#  328577.5625,
#  1129061760.0,
#  25831860.0,
#  57680160.0,
#  20750566.0,
#  6813067.5,
#  1129061760.0,
#  20750562.0,
#  25831856.0,
#  1632438272.0,
#  673687744.0,
#  20833028.0,
#  1129061504.0,
#  2979887872.0,
#  57680132.0,
#  328574.75,
#  9915695.0,
#  173220768.0,
#  243370352.0,
#  30637236.0,
#  173220736.0,
#  104036152.0,
#  57053784.0,
#  6813052.0,
#  12873.7158203125,
#  47755.62890625,
#  673687680.0,
#  57053780.0,
#  184568272.0,
#  360294.5625,
#  47755.21484375,
#  216981472.0,
#  57657312.0,
#  29064032.0,
#  121283264.0,
#  9915681.0,
#  328571.03125,
#  30637220.0,
#  343959712.0,
#  6813042.5,
#  57053768.0,
#  1632437888.0,
#  1129061504.0,
#  155523888.0,
#  9915676.0,
#  216981424.0,
#  735420224.0,
#  9915673.0,
#  57053752.0,
#  328568.9375,
#  735420224.0,
#  12873.0244140625,
#  104036080.0,
#  57053740.0,
#  343959616.0,
#  155523824.0,
#  360292.3125,
#  2979887360.0,
#  20832980.0,
#  47752.7890625,
#  52843012.0,
#  122993992.0,
#  216981376.0,
#  1150979584.0,
#  57680008.0,
#  173220624.0,
#  243370256.0,
#  328565.625,
#  155523776.0,
#  360291.0625,
#  20750460.0,
#  328564.875,
#  12872.416015625,
#  6750.09716796875,
#  57053708.0,
#  57657236.0,
#  735420096.0,
#  20750454.0,
#  6813016.5,
#  6813016.0,
#  125872472.0,
#  343959616.0,
#  57053704.0,
#  20750446.0,
#  12872.1611328125,
#  6749.84521484375,
#  121283136.0,
#  12872.1083984375,
#  57053696.0,
#  343959616.0,
#  173220576.0,
#  1150979328.0,
#  57657224.0,
#  216981328.0,
#  12871.970703125,
#  328561.90625,
#  360289.25,
#  10846.3525390625,
#  20832950.0,
#  125872432.0,
#  10846.3115234375,
#  25831740.0,
#  12871.8291015625,
#  12871.8134765625,
#  30637140.0,
#  29063952.0,
#  47749.640625,
#  57679936.0,
#  673687232.0,
#  10846.2021484375,
#  328560.4375,
#  360288.53125,
#  52842940.0,
#  735419840.0,
#  2979887360.0,
#  12871.6142578125,
#  9915631.0,
#  25831728.0,
#  1753097856.0,
#  1572583168.0,
#  121283088.0,
#  52842916.0,
#  52842908.0,
#  10845.8857421875,
#  125872360.0,
#  216981216.0,
#  57053652.0,
#  735419712.0,
#  155523600.0,
#  47747.73046875,
#  2979887104.0,
#  104035912.0,
#  57657164.0,
#  20832916.0,
#  25831698.0,
#  1572583040.0,
#  104035888.0,
#  30637098.0,
#  1632437120.0,
#  173220448.0,
#  12870.728515625,
#  184567936.0,
#  6812978.0,
#  155523536.0,
#  20750364.0,
#  216981120.0,
#  20750358.0,
#  12870.4951171875,
#  29063894.0,
#  12870.439453125,
#  360284.59375,
#  30637078.0,
#  735419648.0,
#  121282968.0,
#  57657112.0,
#  1632436864.0,
#  6812968.5,
#  29063878.0,
#  328551.28125,
#  1129060736.0,
#  1129060736.0,
#  2979886592.0,
#  6812964.5,
#  1753097728.0,
#  47744.390625,
#  735419456.0,
#  25831646.0,
#  6812959.5,
#  10844.65234375,
#  122993880.0,
#  57053576.0,
#  216981072.0,
#  673686848.0,
#  360282.40625,
#  6812954.5,
#  122993856.0,
#  360282.15625,
#  122993856.0,
#  6812952.0,
#  121282920.0,
#  125872168.0,
#  216981024.0,
#  735419392.0,
#  1150978688.0,
#  360281.5625,
#  1753097344.0,
#  173220320.0,
#  328545.96875,
#  121282896.0,
#  10844.177734375,
#  52842764.0,
#  735419200.0,
#  20750292.0,
#  25831612.0,
#  216980960.0,
#  328544.625,
#  6812940.5,
#  1572582144.0,
#  735419200.0,
#  25831606.0,
#  47741.44921875,
#  1129060352.0,
#  735419200.0,
#  25831602.0,
#  173220288.0,
#  673686592.0,
#  125872080.0,
#  57053516.0,
#  20750270.0,
#  52842724.0,
#  673686592.0,
#  57657016.0,
#  57679676.0,
#  184567696.0,
#  735419136.0,
#  6812927.5,
#  47740.0390625,
#  328540.53125,
#  173220240.0,
#  57679672.0,
#  20750250.0,
#  25831578.0,
#  216980912.0,
#  125872032.0,
#  216980912.0,
#  1129060096.0,
#  735418944.0,
#  328539.0625,
#  20750238.0,
#  1632436224.0,
#  1753096832.0,
#  216980864.0,
#  735418944.0,
#  25831562.0,
#  328537.65625,
#  1150978304.0,
#  243369968.0,
#  1753096832.0,
#  216980864.0,
#  30636954.0,
#  12867.7236328125,
#  30636950.0,
#  20750214.0,
#  216980816.0,
#  6745.49365234375,
#  20750212.0,
#  243369968.0,
#  328535.15625,
#  52842648.0,
#  216980816.0,
#  155523120.0,
#  29063750.0,
#  104035608.0,
#  52842640.0,
#  52842636.0,
#  57656940.0,
#  10842.57421875,
#  47736.9609375,
#  2979885824.0,
#  243369920.0,
#  343959424.0,
#  25831526.0,
#  216980768.0,
#  52842636.0,
#  30636932.0,
#  25831522.0,
#  360274.90625,
#  12867.1142578125,
#  1632435840.0,
#  360274.71875,
#  1150978176.0,
#  1150978176.0,
#  735418688.0,
#  47736.0234375,
#  121282704.0,
#  1632435840.0,
#  25831510.0,
#  1129059840.0,
#  1150978176.0,
#  20750174.0,
#  104035544.0,
#  104035544.0,
#  57053420.0,
#  1753096576.0,
#  216980656.0,
#  125871864.0,
#  173220064.0,
#  10841.89453125,
#  1753096192.0,
#  343959360.0,
#  121282664.0,
#  10841.7861328125,
#  20750152.0,
#  735418624.0,
#  243369840.0,
#  125871832.0,
#  125871824.0,
#  338667680.0,
#  2979885312.0,
#  1632435712.0,
#  6812873.5,
#  2979885312.0,
#  9915484.0,
#  1632435712.0,
#  25831468.0,
#  57053384.0,
#  104035456.0,
#  1150977920.0,
#  29063680.0,
#  25831460.0,
#  2979885312.0,
#  1572580992.0,
#  343959360.0,
#  1572580992.0,
#  1753096192.0,
#  57656844.0,
#  360270.1875,
#  29063664.0,
#  52842508.0,
#  30636852.0,
#  57053352.0,
#  184567360.0,
#  6812852.5,
#  47731.37109375,
#  243369776.0,
#  12865.1875,
#  216980480.0,
#  125871704.0,
#  1572580608.0,
#  57679416.0,
#  25831426.0,
#  57053336.0,
#  6812847.5,
#  216980480.0,
#  20750082.0,
#  6743.00390625,
#  1572580608.0,
#  57053324.0,
#  9915454.0,
#  216980480.0,
#  25831414.0,
#  122993656.0,
#  57656808.0,
#  673685632.0,
#  57053324.0,
#  9915448.0,
#  9915448.0,
#  1150977664.0,
#  184567280.0,
#  328517.5625,
#  216980432.0,
#  1632435072.0,
#  343959232.0,
#  104035352.0,
#  25831396.0,
#  125871632.0,
#  1753095552.0,
#  47728.91015625,
#  1632435072.0,
#  173219856.0,
#  47728.6328125,
#  1632435072.0,
#  47728.4453125,
#  20750044.0,
#  30636794.0,
#  121282448.0,
#  57053292.0,
#  6812825.5,
#  30636788.0,
#  1150977408.0,
#  52842408.0,
#  360265.59375,
#  125871584.0,
#  57679308.0,
#  6812820.5,
#  1150977408.0,
#  1753095552.0,
#  735417856.0,
#  30636772.0,
#  735417856.0,
#  360264.75,
#  104035264.0,
#  20832650.0,
#  173219792.0,
#  216980320.0,
#  216980320.0,
#  57656724.0,
#  1753095296.0,
#  1753095296.0,
#  25831342.0,
#  104035240.0,
#  1129059072.0,
#  25831338.0,
#  216980272.0,
#  216980256.0,
#  1753095296.0,
#  104035216.0,
#  1753095296.0,
#  1150977152.0,
#  328507.625,
#  57053228.0,
#  1150977152.0,
#  47724.59375,
#  10838.7626953125,
#  735417664.0,
#  173219712.0,
#  52842320.0,
#  1129059072.0,
#  328505.40625,
#  29063530.0,
#  20832612.0,
#  1129058944.0,
#  20749958.0,
#  1150976896.0,
#  735417664.0,
#  122993544.0,
#  6812783.5,
#  104035152.0,
#  121282280.0,
#  1150976896.0,
#  360260.0625,
#  6812778.5,
#  2979884288.0,
#  184566992.0,
#  6740.18701171875,
#  121282256.0,
#  343959168.0,
#  1632434304.0,
#  30636682.0,
#  6740.01220703125,
#  30636678.0,
#  30636678.0,
#  52842252.0,
#  343959136.0,
#  155522384.0,
#  47721.1796875,
#  673685056.0,
#  1150976640.0,
#  2979883776.0,
#  20832574.0,
#  343959136.0,
#  360257.8125,
#  121282200.0,
#  216980096.0,
#  125871312.0,
#  338667456.0,
#  47720.046875,
#  673684928.0,
#  12861.1044921875,
#  12861.07421875,
#  47719.6875,
#  155522320.0,
#  1632434048.0,
#  57053140.0,
#  1150976640.0,
#  1129058560.0,
#  1572579072.0,
#  30636636.0,
#  673684864.0,
#  1129058560.0,
#  122993480.0,
#  20749866.0,
#  1572579072.0,
#  328493.03125,
#  25831212.0,
#  104034984.0,
#  328492.1875,
#  121282112.0,
#  1129058176.0,
#  104034984.0,
#  673684608.0,
#  52842148.0,
#  121282096.0,
#  25831192.0,
#  360253.6875,
#  104034960.0,
#  673684608.0,
#  338667360.0,
#  104034936.0,
#  1632433792.0,
#  9915318.0,
#  122993424.0,
#  10836.2314453125,
#  735416896.0,
#  2979882752.0,
#  30636582.0,
#  20749808.0,
#  10836.0478515625,
#  328486.375,
#  735416896.0,
#  328485.90625,
#  52842088.0,
#  57053036.0,
#  125871088.0,
#  328485.0,
#  12859.126953125,
#  29063372.0,
#  125871064.0,
#  735416768.0,
#  735416768.0,
#  1632433152.0,
#  328483.46875,
#  121281984.0,
#  360250.0,
#  216979792.0,
#  125871032.0,
#  735416640.0,
#  1632433152.0,
#  20749762.0,
#  1129057920.0,
#  360249.0,
#  125871000.0,
#  173219280.0,
#  343958976.0,
#  216979744.0,
#  104034808.0,
#  20749740.0,
#  1753093632.0,
#  328478.375,
#  338667296.0,
#  360247.4375,
#  360247.28125,
#  155521936.0,
#  1753093632.0,
#  20832446.0,
#  155521888.0,
#  735416384.0,
#  1632433024.0,
#  121281896.0,
#  47709.28515625,
#  673684160.0,
#  122993320.0,
#  1632432640.0,
#  30636480.0,
#  173219184.0,
#  1150975616.0,
#  343958944.0,
#  1632432640.0,
#  1129057536.0,
#  57052908.0,
#  10833.9443359375,
#  1150975616.0,
#  6812654.0,
#  20749660.0,
#  2979881728.0,
#  184566352.0,
#  122993272.0,
#  57678712.0,
#  360242.4375,
#  20832394.0,
#  216979504.0,
#  30636432.0,
#  57052872.0,
#  104034632.0,
#  1753092736.0,
#  184566288.0,
#  173219040.0,
#  1129057280.0,
#  25830998.0,
#  216979424.0,
#  1632432512.0,
#  1632432512.0,
#  9915208.0,
#  1129057280.0,
#  735415744.0,
#  673683520.0,
#  57052820.0,
#  29063196.0,
#  30636384.0,
#  735415616.0,
#  121281680.0,
#  735415616.0,
#  243369104.0,
#  2979880960.0,
#  1150975104.0,
#  673683520.0,
#  328456.78125,
#  1150975104.0,
#  343958720.0,
#  328455.3125,
#  338667040.0,
#  57678516.0,
#  122993160.0,
#  735415360.0,
#  20749510.0,
#  338667040.0,
#  12853.8974609375,
#  6732.21337890625,
#  360234.03125,
#  155521360.0,
#  1632431616.0,
#  57052712.0,
#  216979168.0,
#  243369072.0,
#  216979168.0,
#  104034392.0,
#  735415232.0,
#  29063108.0,
#  25830868.0,
#  57656128.0,
#  1150974592.0,
#  47695.3984375,
#  735415104.0,
#  12852.9697265625,
#  1632431232.0,
#  216979072.0,
#  104034352.0,
#  360230.5,
#  6731.01416015625,
#  122993080.0,
#  25830836.0,
#  6730.859375,
#  29063066.0,
#  2979879680.0,
#  735414976.0,
#  328442.5,
#  216979024.0,
#  328441.78125,
#  1129056256.0,
#  57052632.0,
#  1129056256.0,
#  360227.84375,
#  1753091456.0,
#  673682816.0,
#  30636220.0,
#  10829.595703125,
#  25830788.0,
#  184565776.0,
#  343958624.0,
#  121281360.0,
#  328436.4375,
#  1572574976.0,
#  1129055872.0,
#  25830766.0,
#  1129055872.0,
#  57656000.0,
#  25830754.0,
#  673682560.0,
#  125870112.0,
#  30636170.0,
#  243368848.0,
#  29062972.0,
#  1129055872.0,
#  57655976.0,
#  125870064.0,
#  12850.2548828125,
#  57678168.0,
#  29062956.0,
#  328428.5625,
#  6812488.0,
#  1632430208.0,
#  360221.21875,
#  184565584.0,
#  10828.076171875,
#  121281216.0,
#  173218352.0,
#  9915047.0,
#  20749266.0,
#  9915045.0,
#  173218352.0,
#  9915042.0,
#  122992904.0,
#  1753090688.0,
#  343958528.0,
#  173218304.0,
#  9915034.0,
#  104034032.0,
#  328422.3125,
#  121281152.0,
#  1753090176.0,
#  1753090176.0,
#  57052440.0,
#  9915023.0,
#  57052424.0,
#  57052424.0,
#  20749206.0,
#  243368752.0,
#  155520624.0,
#  9915012.0,
#  29062870.0,
#  155520576.0,
#  1753090176.0,
#  173218192.0,
#  20832100.0,
#  20749174.0,
#  735413760.0,
#  1632429568.0,
#  20749162.0,
#  57052364.0,
#  243368640.0,
#  9914990.0,
#  121281008.0,
#  2979877632.0,
#  2979877632.0,
#  122992800.0,
#  216978432.0,
#  104033856.0,
#  47675.2890625,
#  10825.65625,
#  25830556.0,
#  735413440.0,
#  1129054848.0]

# %% [markdown]
# # Running one unseen inputs

# %%
# Just return an output given an input
def evaluate(x):
    
    output = model(x)

    return output

# %%
def predict(x):
    with torch.no_grad():
        output = evaluate(x)
    return output

# %%
results = []
for index in range(len(X_test)):
    x = X_test[index]
    output = predict(x)
    results.append(output)

# %%
results[0]
# Out:
# tensor([[[0.1799]],
#
#         [[0.2449]],
#
#         [[0.2678]],
#
#         [[0.2770]],
#
#         [[0.2813]]])
